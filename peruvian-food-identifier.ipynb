# %% [markdown]
# # Training a peruvian food identifier

# %% [markdown]
# In this notebook I will train a model to identify 10 types of peruvian food using fastai library:
#
# * Ceviche
# * Ají de gallina
# * Lomo saltado
# * Causa limeña
# * Rocoto relleno
# * Tacu tacu
# * Anticuchos
# * Pan con chicharrón
# * Olluquito
# * Picante de cuy

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
from fastai import *
from fastai.vision import *

# %%
import fastai.version
fastai.__version__
# Out:
# '1.0.34'

# %%
path = Path('data/peruvian_food')

# %%
path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'ceviche'
file = 'urls_ceviche.txt'

# %%
folder = 'aji_gallina'
file = 'urls_aji_gallina.txt'

# %%
folder = 'lomo_saltado'
file = 'urls_lomo_saltado.txt'

# %%
folder = 'causa_limena'
file = 'urls_causa_limena.txt'

# %%
folder = 'rocoto_relleno'
file = 'urls_rocoto_relleno.txt'

# %%
folder = 'tacu_tacu'
file = 'urls_tacu_tacu.txt'

# %%
folder = 'anticuchos'
file = 'urls_anticuchos.txt'

# %%
folder = 'pan_chicharron'
file = 'urls_pan_chicharron.txt'

# %%
folder = 'olluquito'
file = 'urls_olluquito.txt'

# %%
folder = 'picante_cuy'
file = 'urls_picante_cuy.txt'

# %% [markdown]
# You will need to run this line once per each category.

# %%
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
download_images(path/file, dest, max_pics=400)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 02:15<00:00]
#     </div>
# Error http://www.rmr-peru.com/receta-picante-de-cuy.JPG 'content-length'
# ...

# %%
classes = ['ceviche','aji_gallina','lomo_saltado', 'causa_limena', 'rocoto_relleno', 'tacu_tacu', 'anticuchos',
          'pan_chicharron', 'olluquito', 'picante_cuy']

# %%
# If you have problems download, try with `max_workers=0` to see exceptions:
# download_images(path/file, dest, max_pics=20, max_workers=0)

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# ceviche
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='368' class='' max='368', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [368/368 00:00<00:00]
#     </div>
# cannot identify image file '/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/data/peruvian_food/ceviche/00000117.jpg'
# cannot identify image file '/home/jupyter/tutorials/fastai/course-v3/nbs/dl1/data/peruvian_food/ceviche/00000046.jpg'
# ...

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
np.random.seed(42)

tfms = get_transforms()

src = (ImageItemList.from_folder(path, train=".")
       .random_split_by_pct(0.2)
       .label_from_folder())

data = (src.transform(tfms, size=128)
        .databunch().normalize(imagenet_stats))

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['aji_gallina',
#  'anticuchos',
#  'causa_limena',
#  'ceviche',
#  'lomo_saltado',
#  'olluquito',
#  'pan_chicharron',
#  'picante_cuy',
#  'rocoto_relleno',
#  'tacu_tacu']

# %%
data.show_batch(rows=4, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['aji_gallina',
#   'anticuchos',
#   'causa_limena',
#   'ceviche',
#   'lomo_saltado',
#   'olluquito',
#   'pan_chicharron',
#   'picante_cuy',
#   'rocoto_relleno',
#   'tacu_tacu'],
#  10,
#  2019,
#  504)

# %% [markdown]
# ## Train model Resnet34

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(8, max_lr=slice(3e-3))
# Out:
# Total time: 02:34 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.432580</th>
#     <th>1.478082</th>
#     <th>0.492063</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.706482</th>
#     <th>0.955308</th>
#     <th>0.321429</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.311404</th>
#     <th>0.801320</th>
#     <th>0.271825</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.046867</th>
#     <th>0.758239</th>
#     <th>0.244048</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.870428</th>
#     <th>0.702708</th>
#     <th>0.230159</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.760378</th>
#     <th>0.684182</th>
#     <th>0.216270</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.673090</th>
#     <th>0.676737</th>
#     <th>0.220238</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.614564</th>
# ...

# %%
learn.save('stage-1-r34-bs64-rs42-s128')

# %%
learn.load('stage-1-r34-bs64-rs42-s128')
# Out:
# Learner(data=ImageDataBunch;
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-4))
# Out:
# Total time: 02:59 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.615749</th>
#     <th>0.659929</th>
#     <th>0.200397</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.574540</th>
#     <th>0.641622</th>
#     <th>0.196429</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.540490</th>
#     <th>0.616962</th>
#     <th>0.188492</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.513653</th>
#     <th>0.588420</th>
#     <th>0.178571</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.463387</th>
#     <th>0.571406</th>
#     <th>0.176587</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.442546</th>
#     <th>0.568435</th>
#     <th>0.180556</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.422577</th>
#     <th>0.561074</th>
#     <th>0.178571</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.414002</th>
# ...

# %%
learn.save('stage-2-r34-bs64-rs42-s128')

# %%
learn.load('stage-2-r34-bs64-rs42-s128')
# Out:
# Learner(data=ImageDataBunch;
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(norm_dec=0, dpi=120)

# %% [markdown]
# ## Setting new data

# %%
data = (src.transform(tfms, size=256)
        .databunch(bs=64).normalize(imagenet_stats))

# %%
learn.data = data

# %%
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(8, max_lr=slice(2e-3))
# Out:
# Total time: 03:59 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.612084</th>
#     <th>0.442523</th>
#     <th>0.136905</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.501040</th>
#     <th>0.352364</th>
#     <th>0.113095</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.412226</th>
#     <th>0.334441</th>
#     <th>0.115079</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.345607</th>
#     <th>0.342828</th>
#     <th>0.117063</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.309665</th>
#     <th>0.320896</th>
#     <th>0.103175</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.267100</th>
#     <th>0.318453</th>
#     <th>0.105159</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.239308</th>
#     <th>0.315477</th>
#     <th>0.105159</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.229730</th>
# ...

# %%
learn.save('stage-1-r34-bs64-rs42-s256')

# %%
learn.load('stage-1-r34-bs64-rs42-s256')
# Out:
# Learner(data=ImageDataBunch;
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-4))
# Out:
# Total time: 04:07 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.207250</th>
#     <th>0.304796</th>
#     <th>0.095238</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.208580</th>
#     <th>0.296125</th>
#     <th>0.097222</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.193027</th>
#     <th>0.293286</th>
#     <th>0.093254</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.175881</th>
#     <th>0.282640</th>
#     <th>0.091270</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.158450</th>
#     <th>0.287528</th>
#     <th>0.093254</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.142242</th>
#     <th>0.280934</th>
#     <th>0.097222</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.135569</th>
#     <th>0.276193</th>
#     <th>0.087302</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.128058</th>
# ...

# %%
learn.save('stage-2-r34-bs64-rs42-s256')

# %%
learn.load('stage-2-r34-bs64-rs42-s256')
# Out:
# Learner(data=ImageDataBunch;
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `FileDeleter` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.
#
# First we need to get the file paths from our top_losses. Here's a handy function that pulls out all our top_losses:

# %%
from fastai.widgets import *

#losses,idxs = interp.top_losses()
#top_loss_paths = data.valid_ds.x[idxs]
#fd = ImageDeleter(data, idxs)

#ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Train)
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

ImageCleaner(ds, idxs)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
??ImageCleaner.delete_image

# %% [markdown]
# Now we can pass in these paths to our widget.

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Confirm' to delete flagged photos and keep the rest in that row. The `File_Deleter` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses`.

# %% [markdown]
# ## Putting your model in production

# %%
data.classes
# Out:
# ['aji_gallina',
#  'anticuchos',
#  'causa_limena',
#  'ceviche',
#  'lomo_saltado',
#  'olluquito',
#  'pan_chicharron',
#  'picante_cuy',
#  'rocoto_relleno',
#  'tacu_tacu']

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
# fastai.defaults.device = torch.device('cpu')

# %%
img = open_image(path/'picante_cuy'/'00000021.jpg')
img
# Out:
# Image (3, 325, 635)

# %%
classes = ['ceviche','aji_gallina','lomo_saltado', 'causa_limena', 'rocoto_relleno', 'tacu_tacu', 'anticuchos',
          'pan_chicharron', 'olluquito', 'picante_cuy']
data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224).normalize(imagenet_stats)
learn = create_cnn(data2, models.resnet34)
learn.load('stage-2-r34-bs64-rs42')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# 'aji_gallina'

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Train model Resnet50

# %%
#data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
#        ds_tfms=get_transforms(), size=224, bs = 64//2, num_workers=4).normalize(imagenet_stats)

# %%
np.random.seed(42)

tfms = get_transforms()

src = (ImageItemList.from_folder(path, train=".")
       .random_split_by_pct(0.2)
       .label_from_folder())

data = (src.transform(tfms, size=128)
        .databunch().normalize(imagenet_stats))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['aji_gallina',
#   'anticuchos',
#   'causa_limena',
#   'ceviche',
#   'lomo_saltado',
#   'olluquito',
#   'pan_chicharron',
#   'picante_cuy',
#   'rocoto_relleno',
#   'tacu_tacu'],
#  10,
#  2019,
#  504)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate)

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=slice(3e-3))
# Out:
# Total time: 03:56 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.895506</th>
#     <th>0.971404</th>
#     <th>0.321429</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.291751</th>
#     <th>0.781051</th>
#     <th>0.248016</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.011115</th>
#     <th>0.673142</th>
#     <th>0.224206</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.854826</th>
#     <th>0.627952</th>
#     <th>0.206349</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.696973</th>
#     <th>0.609962</th>
#     <th>0.208333</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.596182</th>
#     <th>0.562083</th>
#     <th>0.182540</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.493079</th>
#     <th>0.561671</th>
#     <th>0.168651</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.433186</th>
# ...

# %%
learn.save('stage-1-r50-bs64-rs42-s128')

# %%
learn.load('stage-1-r50-bs64-rs42-s128')
# Out:
# Learner(data=ImageDataBunch;
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-4))
# Out:
# Total time: 03:13 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.309457</th>
#     <th>0.569821</th>
#     <th>0.170635</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.292310</th>
#     <th>0.543628</th>
#     <th>0.168651</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.298172</th>
#     <th>0.537078</th>
#     <th>0.170635</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.276445</th>
#     <th>0.513796</th>
#     <th>0.164683</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.248980</th>
#     <th>0.511476</th>
#     <th>0.164683</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.229742</th>
#     <th>0.503846</th>
#     <th>0.154762</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.216356</th>
#     <th>0.509015</th>
#     <th>0.162698</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.211679</th>
# ...

# %%
learn.save('stage-2-r50-bs64-rs42-s128')

# %%
learn.load('stage-2-r50-bs64-rs42-s128')
# Out:
# Learner(data=ImageDataBunch;
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ## Setting new data

# %%
data = (src.transform(tfms, size=256)
        .databunch(bs=32).normalize(imagenet_stats))

# %%
learn.data = data

# %%
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-3))
# Out:
# Total time: 04:29 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.476948</th>
#     <th>0.418970</th>
#     <th>0.123016</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.361198</th>
#     <th>0.327773</th>
#     <th>0.095238</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.342394</th>
#     <th>0.310275</th>
#     <th>0.087302</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.273435</th>
#     <th>0.307901</th>
#     <th>0.097222</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.259217</th>
#     <th>0.287038</th>
#     <th>0.087302</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.193717</th>
#     <th>0.265458</th>
#     <th>0.075397</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.169563</th>
#     <th>0.281867</th>
#     <th>0.085317</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.195816</th>
# ...

# %%
learn.save('stage-1-r50-bs32-rs42-s256')

# %%
learn.load('stage-1-r50-bs32-rs42-s256')
# Out:
# Learner(data=ImageDataBunch;
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-4))
# Out:
# Total time: 05:25 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.149775</th>
#     <th>0.262638</th>
#     <th>0.075397</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.155009</th>
#     <th>0.264409</th>
#     <th>0.089286</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.120928</th>
#     <th>0.258438</th>
#     <th>0.091270</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.148452</th>
#     <th>0.242775</th>
#     <th>0.077381</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.184760</th>
#     <th>0.257846</th>
#     <th>0.089286</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.129584</th>
#     <th>0.247915</th>
#     <th>0.077381</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.139714</th>
#     <th>0.254876</th>
#     <th>0.083333</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.141026</th>
# ...

# %%
learn.save('stage-2-r50-bs64-rs42-s256')

# %%
learn.load('stage-2-r50-bs64-rs42-s256')
# Out:
# Learner(data=ImageDataBunch;
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(norm_dec=0, dpi=120)

# %% [markdown]
# ## Setting new data

# %%
data = (src.transform(tfms, size=512)
        .databunch(bs=8).normalize(imagenet_stats))

# %%
learn.data = data

# %%
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 512, 512])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-3))
# Out:
# Total time: 13:34 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.646044</th>
#     <th>0.364398</th>
#     <th>0.121032</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.565557</th>
#     <th>0.373052</th>
#     <th>0.123016</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.451110</th>
#     <th>0.305220</th>
#     <th>0.099206</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.428169</th>
#     <th>0.319500</th>
#     <th>0.113095</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.373403</th>
#     <th>0.269956</th>
#     <th>0.081349</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.334102</th>
#     <th>0.272095</th>
#     <th>0.087302</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.306686</th>
#     <th>0.274305</th>
#     <th>0.087302</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.260241</th>
# ...

# %%
learn.save('stage-1-r50-bs8-rs42-s512')

# %%
learn.load('stage-1-r50-bs8-rs42-s512')
# Out:
# Learner(data=ImageDataBunch;
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-4))
# Out:
# Total time: 18:06 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.268458</th>
#     <th>0.237191</th>
#     <th>0.069444</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.253826</th>
#     <th>0.252228</th>
#     <th>0.077381</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.305721</th>
#     <th>0.275243</th>
#     <th>0.081349</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.270122</th>
#     <th>0.260199</th>
#     <th>0.081349</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.181874</th>
#     <th>0.223307</th>
#     <th>0.069444</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.232626</th>
#     <th>0.217133</th>
#     <th>0.071429</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.214231</th>
#     <th>0.235012</th>
#     <th>0.077381</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.161863</th>
# ...

# %%
learn.save('stage-2-r50-bs8-rs42-s512')

# %%
learn.load('stage-2-r50-bs8-rs42-s512')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (2019 items)
# [Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy, Category picante_cuy]...
# Path: data/peruvian_food
# x: ImageItemList (2019 items)
# [Image (3, 400, 600), Image (3, 562, 747), Image (3, 351, 617), Image (3, 284, 380), Image (3, 400, 700)]...
# Path: data/peruvian_food;
#
# Valid: LabelList
# y: CategoryList (504 items)
# [Category tacu_tacu, Category anticuchos, Category lomo_saltado, Category anticuchos, Category lomo_saltado]...
# Path: data/peruvian_food
# x: ImageItemList (504 items)
# [Image (3, 320, 450), Image (3, 1024, 1024), Image (3, 378, 700), Image (3, 480, 640), Image (3, 697, 1214)]...
# Path: data/peruvian_food;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
learn.save('stage-2-r50-bs8-rs42-s512-no-opt', with_opt=False)

# %%
# ?learn.save
